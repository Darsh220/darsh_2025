# %% [markdown]
# ---
# layout: post
# title: Project Showcase at NATM
# descriptionn: Showcasing Our Projects
# courses: { csp: {week: 6} }
# comments: true
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
